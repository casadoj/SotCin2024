# %%
import numpy as np
import xarray as xr
from pathlib import Path

# %%
VAR = 'rowe'

# %%
PATH = Path(f'Z:/nahaUsers/casadje/GloFASv4/long_run/{VAR}/thresholds')

# %%
avg = xr.open_dataset(PATH / f'avg_{VAR}_1991-1992.nc')[VAR]#.squeeze('time')

# %%
avg.plot(cmap='Blues');

# %%
monthly = xr.open_dataset(PATH / f'{VAR}_monthly_mean_1991-1992.nc')[VAR]

# %%
monthly.plot();
