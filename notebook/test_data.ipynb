# %%
import numpy as np
import xarray as xr
from pathlib import Path

# %%
PATH = Path('Z:/nahaUsers/casadje/GloFASv4/long_run/dis/thresholds')

# %%
avgdis = xr.open_dataset(PATH / 'avg_dis.nc')['dis'].squeeze('time')

# %%
avgdis.plot();
