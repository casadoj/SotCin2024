# %%
import numpy as np
import xarray as xr
from pathlib import Path
from tqdm.auto import tqdm

# %%
# configuration
variable = 'rowe'
base_path = Path('Z:/nahaUsers/casadje/GloFASv4/long_run')
start_date = '1991-01-02'
end_date = '2021-01-01'
output_dir = base_path / variable / 'thresholds'
output_file = output_dir / f'avg_{variable}_xarray.nc'

# %%
# create output directory
output_dir.mkdir(parents=True, exist_ok=True)

# list of input NetCDF files
files = sorted((base_path / variable).glob('*.nc')) #.glob(f'{variable}_*.nc'))
if not files:
    raise FileNotFoundError(f"No files found in {base_path / variable} matching pattern '{variable}_*.nc'.")

# %% [markdown]
# ***

# %%
# open dataset and crop to the study period
ds = xr.open_mfdataset(
    files,
    engine='netcdf4',
    chunks={'time': 365, 'lat': 200, 'lon': 200}
)[variable]

# %%
ds
# Out:
# <xarray.DataArray 'rowe' (valid_time: 12358, latitude: 3000, longitude: 7200)>
# dask.array<concatenate, shape=(12358, 3000, 7200), dtype=float32, chunksize=(366, 3000, 7200), chunktype=numpy.ndarray>
# Coordinates:
#   * valid_time  (valid_time) datetime64[ns] 1991-01-02 1991-01-03 ... 2024-11-01
#     surface     float64 0.0
#   * latitude    (latitude) float64 89.97 89.92 89.88 ... -59.87 -59.92 -59.98
#   * longitude   (longitude) float64 -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
# Attributes:
#     GRIB_paramId:                             231002
#     GRIB_dataType:                            sfo
#     GRIB_numberOfPoints:                      21600000
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            accum
#     GRIB_gridType:                            regular_ll
#     GRIB_uvRelativeToGrid:                    0
#     GRIB_NV:                                  0
#     GRIB_Nx:                                  7200
#     GRIB_Ny:                                  3000
#     GRIB_cfName:                              unknown
#     GRIB_cfVarName:                           rowe
#     GRIB_dateOfModelVersion:                  20221001
#     GRIB_expver:                              0001
#     GRIB_gridDefinitionDescription:           Latitude/longitude
#     GRIB_iDirectionIncrementInDegrees:        0.05
#     GRIB_iScansNegatively:                    0
#     GRIB_jDirectionIncrementInDegrees:        0.05
#     GRIB_jPointsAreConsecutive:               0
#     GRIB_jScansPositively:                    0
#     GRIB_latitudeOfFirstGridPointInDegrees:   89.975
#     GRIB_latitudeOfLastGridPointInDegrees:    -59.975
#     GRIB_longitudeOfFirstGridPointInDegrees:  180.025
#     GRIB_longitudeOfLastGridPointInDegrees:   179.975
#     GRIB_missingValue:                        3.4028234663852886e+38
#     GRIB_name:                                Runoff water equivalent (surfac...
#     GRIB_shortName:                           rowe
#     GRIB_units:                               kg m**-2
#     long_name:                                Runoff water equivalent (surfac...
#     units:                                    kg m**-2
#     standard_name:                            unknown

# %%
ds = ds.sel(time=slice(start_date, end_date))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\xarray\core\indexing.py:72, in group_indexers_by_index(data_obj, indexers, method, tolerance)
#      71 try:
# ---> 72     index = xindexes[key]
#      73     coord = data_obj.coords[key]
#
# KeyError: 'time'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# Cell In [8], line 7
#       1 # open dataset and crop to the study period
#       2 ds = xr.open_mfdataset(
#       3     files,
#       4     engine='netcdf4',
#       5     chunks={'time': 365, 'lat': 200, 'lon': 200}
#       6 )[variable]
# ----> 7 ds = ds.sel(time=slice(start_date, end_date))
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\xarray\core\dataarray.py:1332, in DataArray.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    1223 def sel(
#    1224     self,
#    1225     indexers: Mapping[Any, Any] = None,
#    (...)
#    1229     **indexers_kwargs: Any,
#    1230 ) -> "DataArray":
#    1231     """Return a new DataArray whose data is given by selecting index
#    1232     labels along the specified dimension(s).
#    1233
#    (...)
#    1330     Dimensions without coordinates: points
#    1331     """
# -> 1332     ds = self._to_temp_dataset().sel(
#    1333         indexers=indexers,
#    1334         drop=drop,
#    1335         method=method,
#    1336         tolerance=tolerance,
#    1337         **indexers_kwargs,
#    1338     )
#    1339     return self._from_temp_dataset(ds)
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\xarray\core\dataset.py:2504, in Dataset.sel(self, indexers, method, tolerance, drop, **indexers_kwargs)
#    2443 """Returns a new dataset with each array indexed by tick labels
#    2444 along the specified dimension(s).
#    2445
#    (...)
#    2501 DataArray.sel
#    2502 """
#    2503 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "sel")
# -> 2504 pos_indexers, new_indexes = remap_label_indexers(
#    2505     self, indexers=indexers, method=method, tolerance=tolerance
#    2506 )
#    2507 # TODO: benbovy - flexible indexes: also use variables returned by Index.query
#    2508 # (temporary dirty fix).
#    2509 new_indexes = {k: v[0] for k, v in new_indexes.items()}
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\xarray\core\coordinates.py:421, in remap_label_indexers(obj, indexers, method, tolerance, **indexers_kwargs)
#     414 indexers = either_dict_or_kwargs(indexers, indexers_kwargs, "remap_label_indexers")
#     416 v_indexers = {
#     417     k: v.variable.data if isinstance(v, DataArray) else v
#     418     for k, v in indexers.items()
#     419 }
# --> 421 pos_indexers, new_indexes = indexing.remap_label_indexers(
#     422     obj, v_indexers, method=method, tolerance=tolerance
#     423 )
#     424 # attach indexer's coordinate to pos_indexers
#     425 for k, v in indexers.items():
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\xarray\core\indexing.py:109, in remap_label_indexers(data_obj, indexers, method, tolerance)
#     106 pos_indexers = {}
#     107 new_indexes = {}
# --> 109 indexes, grouped_indexers = group_indexers_by_index(
#     110     data_obj, indexers, method, tolerance
#     111 )
#     113 forward_pos_indexers = grouped_indexers.pop(None, None)
#     114 if forward_pos_indexers is not None:
#
# File C:\DEV\Anaconda3\envs\xr\lib\site-packages\xarray\core\indexing.py:85, in group_indexers_by_index(data_obj, indexers, method, tolerance)
#      83     raise KeyError(f"no index found for coordinate {key}")
#      84 elif key not in data_obj.dims:
# ---> 85     raise KeyError(f"{key} is not a valid dimension or coordinate")
#      86 # key is a dimension without coordinate: we'll reuse the provided labels
#      87 elif method is not None or tolerance is not None:
#
# KeyError: 'time is not a valid dimension or coordinate'

# %%
# compute average
avg_dis = ds.mean('time')

# save output file
avg_dis.to_netcdf(output_file)
print(f'Saved file {output_file}')

# %% [markdown]
# ***

# %%
avg = {}

# %%
for file in tqdm(files, desc='year'):
    print(file)
    break
# Out:
# year:   0%|          | 0/34 [00:00<?, ?it/s]
# Z:\nahaUsers\casadje\GloFASv4\long_run\rowe\rowe_1991.nc

# %%
    ds = xr.open_dataset(file, chunks={'time': 365, 'lat': 'auto', 'lon': 'auto'})[variable]

# %%
ds.rename({'valid_time': 'time'})
# Out:
# <xarray.DataArray 'rowe' (time: 365, latitude: 3000, longitude: 7200)>
# dask.array<open_dataset-f67153599e5b73a1c9200f5b1b8bcdcerowe, shape=(365, 3000, 7200), dtype=float32, chunksize=(365, 3000, 7200), chunktype=numpy.ndarray>
# Coordinates:
#   * time       (time) datetime64[ns] 1991-01-02 1991-01-03 ... 1992-01-01
#     surface    float64 ...
#   * latitude   (latitude) float64 89.97 89.92 89.88 ... -59.87 -59.92 -59.98
#   * longitude  (longitude) float64 -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
# Attributes:
#     GRIB_paramId:                             231002
#     GRIB_dataType:                            sfo
#     GRIB_numberOfPoints:                      21600000
#     GRIB_typeOfLevel:                         surface
#     GRIB_stepUnits:                           1
#     GRIB_stepType:                            accum
#     GRIB_gridType:                            regular_ll
#     GRIB_uvRelativeToGrid:                    0
#     GRIB_NV:                                  0
#     GRIB_Nx:                                  7200
#     GRIB_Ny:                                  3000
#     GRIB_cfName:                              unknown
#     GRIB_cfVarName:                           rowe
#     GRIB_dateOfModelVersion:                  20221001
#     GRIB_expver:                              0001
#     GRIB_gridDefinitionDescription:           Latitude/longitude
#     GRIB_iDirectionIncrementInDegrees:        0.05
#     GRIB_iScansNegatively:                    0
#     GRIB_jDirectionIncrementInDegrees:        0.05
#     GRIB_jPointsAreConsecutive:               0
#     GRIB_jScansPositively:                    0
#     GRIB_latitudeOfFirstGridPointInDegrees:   89.975
#     GRIB_latitudeOfLastGridPointInDegrees:    -59.975
#     GRIB_longitudeOfFirstGridPointInDegrees:  180.025
#     GRIB_longitudeOfLastGridPointInDegrees:   179.975
#     GRIB_missingValue:                        3.4028234663852886e+38
#     GRIB_name:                                Runoff water equivalent (surfac...
#     GRIB_shortName:                           rowe
#     GRIB_units:                               kg m**-2
#     long_name:                                Runoff water equivalent (surfac...
#     units:                                    kg m**-2
#     standard_name:                            unknown

# %%
    temp = ds.mean('time').compute()

# %%
    ds.close()
